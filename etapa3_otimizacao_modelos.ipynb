# %%
# =======================
# ETAPA 3 – OTIMIZAÇÃO DOS MODELOS (GRID SEARCH)
# =======================

from sklearn.model_selection import GridSearchCV

# =======================
# 1. DEFININDO HIPERPARÂMETROS PARA CADA MODELO
# =======================

parametros = {
    'KNN': {
        'n_neighbors': [3, 5, 7, 9]
    },
    'SVM': {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf']
    },
    'Random Forest': {
        'n_estimators': [50, 100, 150],
        'max_depth': [None, 5, 10]
    }
}

# =======================
# 2. APLICANDO GRID SEARCH E AVALIANDO RESULTADOS
# =======================

modelos_base = {
    'KNN': KNeighborsClassifier(),
    'SVM': SVC(),
    'Random Forest': RandomForestClassifier(random_state=42)
}

for nome, modelo in modelos_base.items():
    print(f"\n🔹 Otimizando: {nome}")
    grid = GridSearchCV(modelo, parametros[nome], cv=5, scoring='accuracy')
    grid.fit(X_train, y_train)

    print("Melhores hiperparâmetros:", grid.best_params_)

    melhor_modelo = grid.best_estimator_
    y_pred = melhor_modelo.predict(X_test)

    print("Acurácia após otimização:", accuracy_score(y_test, y_pred))
    print("Matriz de Confusão:\n", confusion_matrix(y_test, y_pred))
    print("Relatório de Classificação:\n", classification_report(y_test, y_pred))
